# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, LSTM, Dense
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
import datetime
import time
import os
# Out:
# 2025-06-29 16:43:39.153897: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# ----------- Step 1: Scrape latest BTCL price from RSEBL -----------
def get_latest_btcl_price():
    options = webdriver.ChromeOptions()
    options.add_argument('--headless')
    options.add_argument('--disable-gpu')

    driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)
    try:
        url = "https://www.rsebl.org.bt/"
        driver.get(url)
        time.sleep(5)

        rows = driver.find_elements(By.CSS_SELECTOR, "table tbody tr")
        for row in rows:
            cols = row.find_elements(By.TAG_NAME, "td")
            if cols and "BTCL" in cols[0].text:
                return float(cols[2].text.strip())
    finally:
        driver.quit()

# %%
# ----------- Step 2: Prepare data and features -----------
def prepare_data(df, window_size=60):
    prices = df['BTCL'].values.reshape(-1, 1)
    scaler = MinMaxScaler()
    scaled_prices = scaler.fit_transform(prices)

    X, y = [], []
    for i in range(window_size, len(scaled_prices)):
        X.append(scaled_prices[i - window_size:i, 0])
        y.append(scaled_prices[i, 0])
    X = np.array(X).reshape(-1, window_size, 1)
    y = np.array(y)

    split = int(len(X) * 0.8)
    return X[:split], X[split:], y[:split], y[split:], scaler, scaled_prices

# %%
# ----------- Step 3: Train LSTM model -----------
def train_model(X_train, y_train, X_test, y_test):
    model = Sequential([
        Input(shape=(X_train.shape[1], 1)),
        LSTM(100, return_sequences=True),
        LSTM(100),
        Dense(1)
    ])
    model.compile(optimizer=Adam(), loss='mean_squared_error')
    early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
    model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test), callbacks=[early_stop])
    return model

# %%
# ----------- Step 4: Predict next-day price -----------
def predict_next_day(model, scaled_prices, latest_price, scaler, window_size=60):
    latest_scaled = scaler.transform(np.array([[latest_price]]))
    updated_scaled = np.append(scaled_prices, latest_scaled, axis=0)
    sequence = updated_scaled[-window_size:].reshape(1, window_size, 1)
    next_day_scaled = model.predict(sequence, verbose=0)
    predicted_price = scaler.inverse_transform(next_day_scaled)
    return predicted_price[0][0]

# %%
# ----------- Step 5: Main pipeline -----------
def main():
    # Load your historical BTCL stock data
    csv_path = "/Users/ugyen/Documents/GitHub/Stockex-btn/Dataset/BTCL.csv"
    df = pd.read_csv(csv_path)
    df['DateTime'] = pd.to_datetime(df['DateTime']).dt.date
    df = df.groupby('DateTime').last().reset_index()

    # Prepare training data
    window_size = 60
    X_train, X_test, y_train, y_test, scaler, scaled_prices = prepare_data(df, window_size)

    # Train model
    model = train_model(X_train, y_train, X_test, y_test)

    # Scrape latest price
    latest_price = get_latest_btcl_price()
    if latest_price is None:
        print("Failed to retrieve latest price from RSEBL website.")
        return

    print(f"Latest BTCL price scraped: Nu. {latest_price}")

    # Predict next-day price
    predicted_price = predict_next_day(model, scaled_prices, latest_price, scaler, window_size)
    print(f"Predicted next-day price based on latest: Nu. {predicted_price:.2f}")

    # Optional: Append scraped price to CSV
    today = datetime.date.today()
    df = pd.concat([df, pd.DataFrame({'DateTime': [today], 'BTCL': [latest_price]})], ignore_index=True)
    df.to_csv("/Users/ugyen/Documents/GitHub/Stockex-btn/updated_stock_data.csv", index=False)

# Run
if __name__ == "__main__":
    main()
# Out:
# Epoch 1/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 10s 140ms/step - loss: 0.0878 - val_loss: 0.0065
# Epoch 2/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 111ms/step - loss: 0.0029 - val_loss: 0.0025
# Epoch 3/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - loss: 8.7847e-04 - val_loss: 0.0023
# Epoch 4/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - loss: 8.4920e-04 - val_loss: 0.0021
# Epoch 5/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 103ms/step - loss: 8.6651e-04 - val_loss: 0.0018
# Epoch 6/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 104ms/step - loss: 7.6779e-04 - val_loss: 0.0015
# Epoch 7/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - loss: 7.3354e-04 - val_loss: 0.0015
# Epoch 8/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - loss: 5.8940e-04 - val_loss: 0.0014
# Epoch 9/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 104ms/step - loss: 4.2847e-04 - val_loss: 0.0014
# Epoch 10/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 104ms/step - loss: 5.6484e-04 - val_loss: 0.0015
# Epoch 11/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - loss: 4.0692e-04 - val_loss: 0.0014
# Epoch 12/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 113ms/step - loss: 3.7733e-04 - val_loss: 0.0013
# Epoch 13/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - loss: 5.6121e-04 - val_loss: 0.0014
# Epoch 14/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - loss: 4.9110e-04 - val_loss: 0.0013
# Epoch 15/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - loss: 3.7071e-04 - val_loss: 0.0012
# Epoch 16/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 112ms/step - loss: 3.6590e-04 - val_loss: 0.0013
# Epoch 17/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - loss: 3.3232e-04 - val_loss: 0.0013
# Epoch 18/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - loss: 2.9664e-04 - val_loss: 0.0012
# Epoch 19/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - loss: 3.0937e-04 - val_loss: 0.0016
# Epoch 20/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 114ms/step - loss: 4.3945e-04 - val_loss: 0.0013
# Epoch 21/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - loss: 3.1784e-04 - val_loss: 0.0012
# Epoch 22/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - loss: 2.8542e-04 - val_loss: 0.0011
# Epoch 23/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - loss: 2.4788e-04 - val_loss: 0.0014
# Epoch 24/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 114ms/step - loss: 4.0944e-04 - val_loss: 0.0011
# Epoch 25/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 112ms/step - loss: 2.6451e-04 - val_loss: 0.0013
# Epoch 26/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 125ms/step - loss: 3.6648e-04 - val_loss: 0.0011
# Epoch 27/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 115ms/step - loss: 3.0466e-04 - val_loss: 0.0017
# Epoch 28/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 121ms/step - loss: 3.9005e-04 - val_loss: 0.0011
# Epoch 29/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 113ms/step - loss: 2.9179e-04 - val_loss: 0.0013
# Epoch 30/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 112ms/step - loss: 3.4435e-04 - val_loss: 0.0014
# Epoch 31/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 115ms/step - loss: 4.4495e-04 - val_loss: 0.0011
# Epoch 32/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 121ms/step - loss: 2.4561e-04 - val_loss: 9.7094e-04
# Epoch 33/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 117ms/step - loss: 3.0298e-04 - val_loss: 0.0013
# Epoch 34/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 114ms/step - loss: 3.0959e-04 - val_loss: 9.6571e-04
# Epoch 35/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 115ms/step - loss: 1.7264e-04 - val_loss: 9.4754e-04
# Epoch 36/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 121ms/step - loss: 2.3147e-04 - val_loss: 0.0016
# Epoch 37/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 119ms/step - loss: 3.2061e-04 - val_loss: 0.0010
# Epoch 38/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 117ms/step - loss: 1.7897e-04 - val_loss: 9.6279e-04
# Epoch 39/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 117ms/step - loss: 2.3422e-04 - val_loss: 0.0010
# Epoch 40/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 125ms/step - loss: 2.2648e-04 - val_loss: 9.5135e-04
# Latest BTCL price scraped: Nu. 600.0
# Predicted next-day price based on latest: Nu. 583.54
